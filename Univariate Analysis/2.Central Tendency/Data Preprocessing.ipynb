# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset

# %%
 #salary has 67 null values
#check why? Not placed so Nan salary.. 
#replace it with central tendency(mean median mode), ---> meaning maridum will be considered as placed 
#entire Row delete ---> need to del 67 where we loss many datas
#respective to the problem statement, replace the missing values ---> quantitative repace with 0
#consider as semi supervised and create ML model so we can predict the missing values --> regression but not suitable as it changes to placed

#if marks column is missing we can use central tendency

# %%
dataset.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset.isna().sum()

# %%
#if variable is given there is no need to give inplace, if we give like this it means directly change in dataset itself
dataset["salary"].fillna(0,inplace=True)

# %%
dataset.isnull().sum()

# %%
# delete entire row
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
dataset["salary"].fillna(dataset["salary"].mean(),inplace=True) #replacing null values with mean values, this is for single column

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        #print(columnName)
        if (dataset[columnName].dtype=='O'):
            #print('qual')
            qual.append(columnName)
        else:
            #print('quan')
            quan.append(columnName)
    return quan, qual

# %%
quan,qual=quanQual(dataset)

# %%
dataset[quan]
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0        1  67.00  91.00     58.00     55.0  58.80  270000.0
# 1        2  79.33  78.33     77.48     86.5  66.28  200000.0
# 2        3  65.00  68.00     64.00     75.0  57.80  250000.0
# 4        5  85.80  73.60     73.30     96.8  55.50  425000.0
# 7        8  82.00  64.00     66.00     67.0  62.14  252000.0
# ..     ...    ...    ...       ...      ...    ...       ...
# 209    210  62.00  72.00     65.00     67.0  56.49  216000.0
# 210    211  80.60  82.00     77.60     91.0  74.49  400000.0
# 211    212  58.00  60.00     72.00     74.0  53.62  275000.0
# 212    213  67.00  67.00     73.00     59.0  69.72  295000.0
# 213    214  74.00  66.00     58.00     70.0  60.23  204000.0
#
# [148 rows x 7 columns]

# %%
#this method is for finding mean , median for all columns in dataset, for replacing null values 
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(dataset[quan])
dataset=imp.transform(dataset[quan])

# %%
imp
# Out:
# SimpleImputer()

# %%
dataset
# Out:
# array([[1.000e+00, 6.700e+01, 9.100e+01, ..., 5.500e+01, 5.880e+01,
#         2.700e+05],
#        [2.000e+00, 7.933e+01, 7.833e+01, ..., 8.650e+01, 6.628e+01,
#         2.000e+05],
#        [3.000e+00, 6.500e+01, 6.800e+01, ..., 7.500e+01, 5.780e+01,
#         2.500e+05],
#        ...,
#        [2.120e+02, 5.800e+01, 6.000e+01, ..., 7.400e+01, 5.362e+01,
#         2.750e+05],
#        [2.130e+02, 6.700e+01, 6.700e+01, ..., 5.900e+01, 6.972e+01,
#         2.950e+05],
#        [2.140e+02, 7.400e+01, 6.600e+01, ..., 7.000e+01, 6.023e+01,
#         2.040e+05]])

# %%
#for categorical data if there are null values we can take mode..
#create ML model, semi supervised,classification

# %%
#kaggle--dataset-->google it
